# %%
# %load_ext autoreload
# %autoreload 2
from Utils import Histories
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
hist = Histories("utkteam/CartPole-v1-ann")
hist.plot(n=5)
hist.plot(n=5, agg="mean", range="std", range_n=25)
# Out:
# # Plot: Running Reward vs Episode
# # Plot: Running Reward vs Episode

# %%
hist = Histories("utkteam/CartPole-v1-snn")
hist.plot(n=5)
hist.plot(n=5, agg="mean", range="std", range_n=25)
# Out:
# # Plot: Running Reward vs Episode
# # Plot: Running Reward vs Episode

# %%
hypers = ["LR", "H2", "Dropout", "Gamma"]

for hyper in hypers:
    hist = Histories(f"utkteam/CartPole-v1-snn-{hyper}")
    hist.boxplot(hyper)

# %%
hist = Histories("utkteam/CartPole-v1-snn-best_overall")
hist.plot(n=5)
hist.plot(n=5, agg="mean", range="std", range_n=25)
# Out:
# # Plot: Running Reward vs Episode
# # Plot: Running Reward vs Episode

# %%
hypers = ["LR", "H1", "H2", "Dropout", "Gamma"]

for hyper in hypers:
    hist = Histories(f"utkteam/CartPole-v1-ann-{hyper}")
    hist.boxplot(hyper)

# %%
hist = Histories("utkteam/CartPole-v1-ann-best_overall_1000")
hist.plot(n=5)
hist.plot(n=5, agg="mean", range="std", range_n=25)
# Out:
# # Plot: Running Reward vs Episode
# # Plot: Running Reward vs Episode
